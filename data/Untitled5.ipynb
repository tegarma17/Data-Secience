# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %%
elektro = pd.read_csv('elektro1.csv', index_col = 'tanggal_pembelian', parse_dates=True)

# %%
pd.read_csv('elektro1.csv')
# Out:
#                                             nama_barang              merk  \
# 0                        UKA 32'' HD Digital TV   Black               UKA
# 1     Vision Plus VP8832S 32"   HD Android Smart TV ...       Vision Plus
# 2                         UKA 32"   HD Smart TV   Black               UKA
# 3        Hifinit By Haier 24" LED HD DIGITAL TV   Black  Hifinit By Haier
# 4     Vision Plus VP8843C   43"   FHD Android TV Bla...       Vision Plus
# ...                                                 ...               ...
# 1833  Generic Indoor Digital TV Antenna HD Signal Fl...           Generic
# 1834  Royal Sound RS205BT 2.1CH Speaker System 20W  ...       Royal Sound
# 1835  Generic OR HDMI to VGA D SUB Male Video Adapte...           Generic
# 1836  Vitron 24" HD   Digital  LED Backlight TV   Au...            Vitron
# 1837  LG Tv Universal Remote Control For Digital & S...                LG
#
#       stok_barang   harga_lama harga_baru discount_percent  \
# ...

# %%
elektro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1838 entries, Nasco 32C1NA    32"   Digital    HD LED TV   Black to Polysonic Mp 74 Multimedia Speaker 2.1
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   merk               1834 non-null   object
#  1   stok_barang        1838 non-null   int64
#  2   harga_lama         1663 non-null   object
#  3   harga_baru         1838 non-null   object
#  4   discount_percent   1663 non-null   object
#  5   description        1174 non-null   object
#  6   rating_penjualan   1838 non-null   object
#  7   total_terjual      1838 non-null   float64
#  8   total_pemasukan    1838 non-null   object
#  9   tanggal_pembelian  1838 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 198.0+ KB

# %%
elektro.sort_values(by='total_terjual', ascending=False)
# Out:
#                                                          nama_barang  \
# tanggal_pembelian
# 2019-05-19                             UKA 32"   HD Smart TV   Black
# 2019-10-06            Hifinit By Haier 24" LED HD DIGITAL TV   Black
# 2019-09-26         Vision Plus VP8843C   43"   FHD Android TV Bla...
# 2019-06-02         Vision Plus VP8843S 43" FHD SMART Android LED ...
# 2019-09-30         Vision Plus VP8843S 43" FHD SMART Android LED ...
# ...                                                              ...
# 2019-06-25         Generic TWS N9 Sports Earphones Stereo Wire le...
# 2018-01-30                        Remote Control GoTV Remote   Black
# 2019-08-25         Generic FBI Style Interphone In Ear Headset wi...
# 2019-06-04         TAGWOOD MP 631A Multimedia Speaker System 3.1C...
# 2018-03-20         LG Tv Universal Remote Control For Digital & S...
#
#                                merk  stok_barang   harga_lama harga_baru  \
# tanggal_pembelian
# ...

# %%
weekly = elektro.resample('W').sum()

# %%
weekly
# Out:
#                    stok_barang  total_terjual
# tanggal_pembelian
# 2018-01-07                 721           47.0
# 2018-01-14                 958           99.0
# 2018-01-21                1022          138.0
# 2018-01-28                 809          139.0
# 2018-02-04                1057           55.0
# ...                        ...            ...
# 2019-12-08                1003           90.0
# 2019-12-15                 575           63.0
# 2019-12-22                 837          161.0
# 2019-12-29                 728          138.0
# 2020-01-05                 343           10.0
#
# [105 rows x 2 columns]

# %%
month = elektro.resample('M').sum()

# %%
month
# Out:
#                    stok_barang  total_terjual
# tanggal_pembelian
# 2018-01-31                3888        445.000
# 2018-02-28                3571        314.000
# 2018-03-31                3592       1477.000
# 2018-04-30                5300       1264.000
# 2018-05-31                3907        606.000
# 2018-06-30                4669        644.000
# 2018-07-31                3773        635.000
# 2018-08-31                5492        990.000
# 2018-09-30                4002        714.000
# 2018-10-31                5562       1055.000
# 2018-11-30                4623       1048.000
# 2018-12-31                4243        628.005
# 2019-01-31                3653        440.000
# 2019-02-28                3434        684.000
# 2019-03-31                5369        766.246
# 2019-04-30                3491        585.000
# 2019-05-31                3332       2105.000
# 2019-06-30                4634       1796.000
# 2019-07-31                4293       1172.000
# ...

# %%
year = elektro.resample('Y').sum()

# %%
year
# Out:
#                    stok_barang  total_terjual
# tanggal_pembelian
# 2018-12-31               52622       9820.005
# 2019-12-31               47958      13379.246

# %%
total_terjual = elektro['total_terjual']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_1bulan = elektro.loc['2018-01':'2018-01-30']

# %%
data_1bulan.plot()

# %%
data_1minggu = elektro.loc['2018-01-01':'2018-01-08']

# %%
data_1minggu.plot()

# %%
data_1tahun = elektro.loc['2018':'2019']

# %%
data_1tahun.plot();
